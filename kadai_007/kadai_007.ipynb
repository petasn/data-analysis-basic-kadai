# %%
# インポート
import matplotlib.pyplot as plt
import pandas as pd
import japanize_matplotlib

# csvファイルをデータフレームとして読み込む
df = pd.read_csv("sample_pandas_6.csv")
category_df = pd.read_csv('category.csv')

# マージ
df = pd.merge(df, category_df[['商品番号', 'カテゴリー']], how='inner', on='商品番号')

# 抽出頻度をカウントして棒グラフを作成
df['カテゴリー'].value_counts().plot(kind='bar')

# 表示調整
plt.xticks(rotation=0)
plt.tight_layout()

# グラフを表示
plt.show()

# 商品番号ごとに「注文数」の基本統計量を算出
product_stats = df.groupby('商品番号')['注文数'].describe()

# 合計（sum）列を追加
product_stats['sum'] = df.groupby('商品番号')['注文数'].sum()

# 結果を表示
print(product_stats)
# Out:
#           count       mean        std  min   25%   50%   75%   max   sum
# 商品番号
# 1QJFO8QY   32.0  35.250000  18.461818  0.0  24.0  36.0  49.5  60.0  1128
# 2HSTCDWM   20.0  29.400000  21.137146  0.0  12.0  27.0  48.0  60.0   588
# 48XMJXKO   10.0  21.600000  13.326665  0.0  13.5  21.0  30.0  42.0   216
# 8T7D5DQA   21.0  25.142857  18.260027  0.0  12.0  36.0  42.0  54.0   528
# MESUDVWQ   17.0  43.764706  18.219253  0.0  42.0  48.0  54.0  60.0   744
# QRMOGNUU   27.0  33.111111  16.588535  6.0  21.0  36.0  48.0  60.0   894
# S6RE8W6X   20.0  33.300000  21.631118  0.0  12.0  39.0  54.0  60.0   666
# X0ZE2ZMY   14.0  21.857143  21.901377  0.0   1.5  15.0  39.0  60.0   306
# YY4HAAZR   17.0  31.764706  18.095336  0.0  18.0  30.0  42.0  60.0   540
# Z4WOOIYV   22.0  26.727273  19.218498  0.0  12.0  24.0  42.0  60.0   588
