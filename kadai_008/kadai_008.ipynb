# %%
# step1
# 1.サンプルデータの取得
from sklearn.datasets import load_wine
dataset = load_wine()

# 2.サンプルデータの分割
X = dataset.data    #説明変数（ワインの成分）
y = dataset.target  #目的変数（ワインの種別）
# 関数のインポートと実行
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=5)
print(f"分割後={X.shape, X_train.shape, X_test.shape, y.shape, y_train.shape, y_test.shape}")

# step2
# 予測モデル(ランダムフォレスト)のインスタンス化
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=3)

# setp3
# 予測モデルの学習
model.fit(X_train, y_train)
# 予測モデルの評価
y_pred = model.predict(X_test)
print(f"予測値={y_pred}")
print(f"テストデータ={y_test}")
# 正解率
from sklearn.metrics import accuracy_score
result = accuracy_score(y_test, y_pred)
print(f"正解率={result}")
# Out:
# 分割後=((178, 13), (124, 13), (54, 13), (178,), (124,), (54,))
# 予測値=[0 1 0 0 2 2 0 0 1 0 0 0 2 1 2 0 1 0 1 1 0 0 1 1 1 1 0 2 2 0 1 1 0 0 2 2 0
#  2 2 1 1 2 2 0 2 1 0 2 0 1 0 1 1 0]
# テストデータ=[0 1 0 0 2 2 0 0 1 0 0 0 2 1 2 0 1 0 1 0 0 0 1 1 1 1 0 2 2 0 1 1 0 0 2 2 0
#  2 2 1 1 1 2 0 2 1 0 2 0 1 0 1 1 0]
# 正解率=0.9629629629629629
